# %% [markdown]
# # Adding Regularization with l2 and Dropout

# %%
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"   # for ignoring information messages from tensorflow

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.datasets import cifar10

physical_devices = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0


def my_model():
    inputs = keras.Input(shape=(32, 32, 3))
    x = layers.Conv2D(32, 3, padding="same", kernel_regularizer=regularizers.l2(0.01),)(
        inputs
    )
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(64, 3, padding="same", kernel_regularizer=regularizers.l2(0.01),)(
        x
    )
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(
        128, 3, padding="same", kernel_regularizer=regularizers.l2(0.01),
    )(x)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.01),)(
        x
    )
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(10)(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model


model = my_model()
model.compile(
    # HERE WE ARE TELLING KEARS HOW CONFIGURE THE TRAINING PART OF OUR NETWORKS.
    # 1. HERE WE ARE USING SPARSECATEGORICALCROSSENTROPY AND MAKING from_logits=False 
    # beacuse in our output layers we not apply softmax activation function.
    # 2. HERE WE ARE USING ADAM OPTIMIZER WITH 0.001 LEARNING RATE
    # 3. FOR EVALUATING WE ARE USING ACCURACY
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.Adam(lr=3e-4),
    metrics=["accuracy"],
)

model.fit(x_train, y_train, batch_size=64, epochs=150, verbose=2)
model.evaluate(x_test, y_test, batch_size=64, verbose=2)
# Out:
# Epoch 1/150
# 782/782 - 8s - loss: 3.0852 - accuracy: 0.3479
# Epoch 2/150
# 782/782 - 7s - loss: 1.9469 - accuracy: 0.4715
# Epoch 3/150
# 782/782 - 7s - loss: 1.6493 - accuracy: 0.5140
# Epoch 4/150
# 782/782 - 7s - loss: 1.5076 - accuracy: 0.5478
# Epoch 5/150
# 782/782 - 7s - loss: 1.4418 - accuracy: 0.5654
# Epoch 6/150
# 782/782 - 7s - loss: 1.3846 - accuracy: 0.5847
# Epoch 7/150
# 782/782 - 7s - loss: 1.3498 - accuracy: 0.5968
# Epoch 8/150
# 782/782 - 7s - loss: 1.3323 - accuracy: 0.6042
# Epoch 9/150
# 782/782 - 7s - loss: 1.3064 - accuracy: 0.6117
# Epoch 10/150
# 782/782 - 7s - loss: 1.2926 - accuracy: 0.6176
# Epoch 11/150
# 782/782 - 7s - loss: 1.2700 - accuracy: 0.6268
# Epoch 12/150
# 782/782 - 7s - loss: 1.2562 - accuracy: 0.6343
# Epoch 13/150
# 782/782 - 7s - loss: 1.2409 - accuracy: 0.6384
# Epoch 14/150
# 782/782 - 7s - loss: 1.2279 - accuracy: 0.6433
# Epoch 15/150
# 782/782 - 7s - loss: 1.2184 - accuracy: 0.6497
# Epoch 16/150
# 782/782 - 7s - loss: 1.2060 - accuracy: 0.6562
# Epoch 17/150
# 782/782 - 7s - loss: 1.1924 - accuracy: 0.6638
# Epoch 18/150
# 782/782 - 7s - loss: 1.1825 - accuracy: 0.6653
# Epoch 19/150
# 782/782 - 7s - loss: 1.1762 - accuracy: 0.6685
# Epoch 20/150
# 782/782 - 7s - loss: 1.1642 - accuracy: 0.6752
# Epoch 21/150
# 782/782 - 7s - loss: 1.1547 - accuracy: 0.6764
# Epoch 22/150
# 782/782 - 7s - loss: 1.1512 - accuracy: 0.6789
# Epoch 23/150
# 782/782 - 7s - loss: 1.1515 - accuracy: 0.6837
# Epoch 24/150
# 782/782 - 7s - loss: 1.1367 - accuracy: 0.6851
# Epoch 25/150
# 782/782 - 7s - loss: 1.1288 - accuracy: 0.6902
# Epoch 26/150
# 782/782 - 7s - loss: 1.1206 - accuracy: 0.6930
# Epoch 27/150
# 782/782 - 7s - loss: 1.1126 - accuracy: 0.6971
# Epoch 28/150
# 782/782 - 7s - loss: 1.1034 - accuracy: 0.7014
# Epoch 29/150
# 782/782 - 7s - loss: 1.1071 - accuracy: 0.6985
# Epoch 30/150
# 782/782 - 7s - loss: 1.0938 - accuracy: 0.7047
# Epoch 31/150
# 782/782 - 7s - loss: 1.0911 - accuracy: 0.7062
# Epoch 32/150
# 782/782 - 7s - loss: 1.0915 - accuracy: 0.7076
# Epoch 33/150
# 782/782 - 7s - loss: 1.0792 - accuracy: 0.7134
# Epoch 34/150
# 782/782 - 7s - loss: 1.0746 - accuracy: 0.7124
# Epoch 35/150
# 782/782 - 7s - loss: 1.0653 - accuracy: 0.7162
# Epoch 36/150
# 782/782 - 7s - loss: 1.0642 - accuracy: 0.7210
# Epoch 37/150
# 782/782 - 7s - loss: 1.0642 - accuracy: 0.7168
# Epoch 38/150
# 782/782 - 7s - loss: 1.0584 - accuracy: 0.7194
# Epoch 39/150
# 782/782 - 7s - loss: 1.0456 - accuracy: 0.7274
# Epoch 40/150
# 782/782 - 7s - loss: 1.0504 - accuracy: 0.7251
# Epoch 41/150
# 782/782 - 7s - loss: 1.0407 - accuracy: 0.7267
# Epoch 42/150
# 782/782 - 7s - loss: 1.0338 - accuracy: 0.7290
# Epoch 43/150
# 782/782 - 7s - loss: 1.0360 - accuracy: 0.7319
# Epoch 44/150
# 782/782 - 7s - loss: 1.0238 - accuracy: 0.7330
# Epoch 45/150
# 782/782 - 7s - loss: 1.0318 - accuracy: 0.7319
# Epoch 46/150
# 782/782 - 7s - loss: 1.0301 - accuracy: 0.7338
# Epoch 47/150
# 782/782 - 7s - loss: 1.0118 - accuracy: 0.7411
# Epoch 48/150
# 782/782 - 7s - loss: 1.0133 - accuracy: 0.7396
# Epoch 49/150
# 782/782 - 7s - loss: 1.0073 - accuracy: 0.7429
# Epoch 50/150
# 782/782 - 7s - loss: 1.0089 - accuracy: 0.7417
# Epoch 51/150
# 782/782 - 7s - loss: 1.0081 - accuracy: 0.7421
# Epoch 52/150
# 782/782 - 7s - loss: 1.0024 - accuracy: 0.7453
# Epoch 53/150
# 782/782 - 7s - loss: 0.9952 - accuracy: 0.7475
# Epoch 54/150
# 782/782 - 7s - loss: 1.0001 - accuracy: 0.7440
# Epoch 55/150
# 782/782 - 7s - loss: 0.9940 - accuracy: 0.7488
# Epoch 56/150
# 782/782 - 7s - loss: 0.9953 - accuracy: 0.7500
# Epoch 57/150
# 782/782 - 7s - loss: 0.9832 - accuracy: 0.7561
# Epoch 58/150
# 782/782 - 7s - loss: 0.9794 - accuracy: 0.7567
# Epoch 59/150
# 782/782 - 7s - loss: 0.9875 - accuracy: 0.7557
# Epoch 60/150
# 782/782 - 7s - loss: 0.9864 - accuracy: 0.7544
# Epoch 61/150
# 782/782 - 7s - loss: 0.9721 - accuracy: 0.7581
# Epoch 62/150
# 782/782 - 7s - loss: 0.9767 - accuracy: 0.7569
# Epoch 63/150
# 782/782 - 7s - loss: 0.9758 - accuracy: 0.7580
# Epoch 64/150
# 782/782 - 7s - loss: 0.9720 - accuracy: 0.7592
# Epoch 65/150
# 782/782 - 7s - loss: 0.9706 - accuracy: 0.7593
# Epoch 66/150
# 782/782 - 7s - loss: 0.9636 - accuracy: 0.7637
# Epoch 67/150
# 782/782 - 7s - loss: 0.9599 - accuracy: 0.7662
# Epoch 68/150
# 782/782 - 7s - loss: 0.9634 - accuracy: 0.7620
# Epoch 69/150
# 782/782 - 7s - loss: 0.9674 - accuracy: 0.7626
# Epoch 70/150
# 782/782 - 7s - loss: 0.9642 - accuracy: 0.7647
# Epoch 71/150
# 782/782 - 7s - loss: 0.9593 - accuracy: 0.7664
# Epoch 72/150
# 782/782 - 7s - loss: 0.9618 - accuracy: 0.7666
# Epoch 73/150
# 782/782 - 7s - loss: 0.9526 - accuracy: 0.7713
# Epoch 74/150
# 782/782 - 7s - loss: 0.9487 - accuracy: 0.7712
# Epoch 75/150
# 782/782 - 7s - loss: 0.9531 - accuracy: 0.7723
# Epoch 76/150
# 782/782 - 7s - loss: 0.9514 - accuracy: 0.7720
# Epoch 77/150
# 782/782 - 7s - loss: 0.9454 - accuracy: 0.7732
# Epoch 78/150
# 782/782 - 7s - loss: 0.9523 - accuracy: 0.7726
# Epoch 79/150
# 782/782 - 7s - loss: 0.9482 - accuracy: 0.7728
# Epoch 80/150
# 782/782 - 7s - loss: 0.9407 - accuracy: 0.7757
# Epoch 81/150
# 782/782 - 7s - loss: 0.9386 - accuracy: 0.7785
# Epoch 82/150
# 782/782 - 7s - loss: 0.9421 - accuracy: 0.7763
# Epoch 83/150
# 782/782 - 7s - loss: 0.9437 - accuracy: 0.7753
# Epoch 84/150
# 782/782 - 7s - loss: 0.9395 - accuracy: 0.7773
# Epoch 85/150
# 782/782 - 7s - loss: 0.9384 - accuracy: 0.7795
# Epoch 86/150
# 782/782 - 7s - loss: 0.9376 - accuracy: 0.7786
# Epoch 87/150
# 782/782 - 7s - loss: 0.9341 - accuracy: 0.7807
# Epoch 88/150
# 782/782 - 7s - loss: 0.9359 - accuracy: 0.7802
# Epoch 89/150
# 782/782 - 7s - loss: 0.9334 - accuracy: 0.7802
# Epoch 90/150
# 782/782 - 7s - loss: 0.9287 - accuracy: 0.7828
# Epoch 91/150
# 782/782 - 7s - loss: 0.9240 - accuracy: 0.7861
# Epoch 92/150
# 782/782 - 7s - loss: 0.9277 - accuracy: 0.7832
# Epoch 93/150
# 782/782 - 7s - loss: 0.9246 - accuracy: 0.7857
# Epoch 94/150
# 782/782 - 7s - loss: 0.9282 - accuracy: 0.7852
# Epoch 95/150
# 782/782 - 7s - loss: 0.9213 - accuracy: 0.7867
# Epoch 96/150
# 782/782 - 7s - loss: 0.9266 - accuracy: 0.7875
# Epoch 97/150
# 782/782 - 7s - loss: 0.9186 - accuracy: 0.7867
# Epoch 98/150
# 782/782 - 7s - loss: 0.9195 - accuracy: 0.7889
# Epoch 99/150
# 782/782 - 7s - loss: 0.9177 - accuracy: 0.7906
# Epoch 100/150
# 782/782 - 7s - loss: 0.9282 - accuracy: 0.7850
# Epoch 101/150
# 782/782 - 7s - loss: 0.9262 - accuracy: 0.7859
# Epoch 102/150
# 782/782 - 7s - loss: 0.9156 - accuracy: 0.7895
# Epoch 103/150
# 782/782 - 7s - loss: 0.9168 - accuracy: 0.7923
# Epoch 104/150
# 782/782 - 7s - loss: 0.9149 - accuracy: 0.7899
# Epoch 105/150
# 782/782 - 7s - loss: 0.9236 - accuracy: 0.7884
# Epoch 106/150
# 782/782 - 7s - loss: 0.9089 - accuracy: 0.7938
# Epoch 107/150
# 782/782 - 7s - loss: 0.9118 - accuracy: 0.7927
# Epoch 108/150
# 782/782 - 7s - loss: 0.9193 - accuracy: 0.7920
# Epoch 109/150
# 782/782 - 7s - loss: 0.9122 - accuracy: 0.7930
# Epoch 110/150
# 782/782 - 7s - loss: 0.9033 - accuracy: 0.7955
# Epoch 111/150
# 782/782 - 7s - loss: 0.9152 - accuracy: 0.7935
# Epoch 112/150
# 782/782 - 7s - loss: 0.9119 - accuracy: 0.7943
# Epoch 113/150
# 782/782 - 7s - loss: 0.9068 - accuracy: 0.7972
# Epoch 114/150
# 782/782 - 7s - loss: 0.9119 - accuracy: 0.7952
# Epoch 115/150
# 782/782 - 7s - loss: 0.9053 - accuracy: 0.7953
# Epoch 116/150
# 782/782 - 7s - loss: 0.9052 - accuracy: 0.7973
# Epoch 117/150
# 782/782 - 7s - loss: 0.9081 - accuracy: 0.7956
# Epoch 118/150
# 782/782 - 7s - loss: 0.9038 - accuracy: 0.7968
# Epoch 119/150
# 782/782 - 7s - loss: 0.9050 - accuracy: 0.7982
# Epoch 120/150
# 782/782 - 7s - loss: 0.9012 - accuracy: 0.8009
# Epoch 121/150
# 782/782 - 7s - loss: 0.9051 - accuracy: 0.8006
# Epoch 122/150
# 782/782 - 7s - loss: 0.9084 - accuracy: 0.7975
# Epoch 123/150
# 782/782 - 7s - loss: 0.8997 - accuracy: 0.7998
# Epoch 124/150
# 782/782 - 7s - loss: 0.8936 - accuracy: 0.8019
# Epoch 125/150
# 782/782 - 7s - loss: 0.9033 - accuracy: 0.8004
# Epoch 126/150
# 782/782 - 7s - loss: 0.8970 - accuracy: 0.8025
# Epoch 127/150
# 782/782 - 7s - loss: 0.8966 - accuracy: 0.8020
# Epoch 128/150
# 782/782 - 7s - loss: 0.9018 - accuracy: 0.7995
# Epoch 129/150
# 782/782 - 7s - loss: 0.9022 - accuracy: 0.8003
# Epoch 130/150
# 782/782 - 7s - loss: 0.8995 - accuracy: 0.8032
# Epoch 131/150
# 782/782 - 7s - loss: 0.9056 - accuracy: 0.8010
# Epoch 132/150
# 782/782 - 7s - loss: 0.8948 - accuracy: 0.8052
# Epoch 133/150
# 782/782 - 7s - loss: 0.8943 - accuracy: 0.8031
# Epoch 134/150
# 782/782 - 7s - loss: 0.8972 - accuracy: 0.8014
# Epoch 135/150
# 782/782 - 7s - loss: 0.8949 - accuracy: 0.8034
# Epoch 136/150
# 782/782 - 7s - loss: 0.8966 - accuracy: 0.8025
# Epoch 137/150
# 782/782 - 7s - loss: 0.8950 - accuracy: 0.8050
# Epoch 138/150
# 782/782 - 7s - loss: 0.8990 - accuracy: 0.8058
# Epoch 139/150
# 782/782 - 7s - loss: 0.9005 - accuracy: 0.8040
# Epoch 140/150
# 782/782 - 7s - loss: 0.8907 - accuracy: 0.8089
# Epoch 141/150
# 782/782 - 7s - loss: 0.8909 - accuracy: 0.8055
# Epoch 142/150
# 782/782 - 7s - loss: 0.8936 - accuracy: 0.8056
# Epoch 143/150
# 782/782 - 7s - loss: 0.8882 - accuracy: 0.8079
# Epoch 144/150
# 782/782 - 7s - loss: 0.8916 - accuracy: 0.8068
# Epoch 145/150
# 782/782 - 7s - loss: 0.8920 - accuracy: 0.8064
# Epoch 146/150
# 782/782 - 7s - loss: 0.9018 - accuracy: 0.8022
# Epoch 147/150
# 782/782 - 7s - loss: 0.8830 - accuracy: 0.8101
# Epoch 148/150
# 782/782 - 7s - loss: 0.8933 - accuracy: 0.8069
# Epoch 149/150
# 782/782 - 7s - loss: 0.8880 - accuracy: 0.8084
# Epoch 150/150
# 782/782 - 7s - loss: 0.8859 - accuracy: 0.8091
# 157/157 - 1s - loss: 1.1241 - accuracy: 0.7497
# [1.1241188049316406, 0.7497000098228455]
